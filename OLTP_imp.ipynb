# %%
#import
import sqlite3   #light weight database
import pandas as pd
import time
from datetime import datetime

#connection to our oltp database 
conn=sqlite3.connect('unisole_rides.db')    #conn acts as a opening or connectivity todatabasr
cursor=conn.cursor()   # cursor executes sql query

print("OLTP database initialization")
# Out:
# OLTP database initialization

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 4, 24, 22, 2, 2, 862926)

# %%
## creating table with constraints
cursor.execute ('''
CREATE TABLE IF NOT EXISTS rides(
    ride_id INTEGER PRIMARY KEY AUTOINCREMENT,
    user_id TEXT NOT NULL,
    driver_id TEXT,
    pickup_location TEXT,
    destination TEXT,
    status TEXT CHECK ( status IN 
    ('requested','ongoing','completed','cancelled')),
    price REAL,
    timestamp DATETIME DEFAULT CURRENT_TIMESTAMP                                    )                                                                         
   
''')              
conn.commit()
print("table created")
# Out:
# table created
